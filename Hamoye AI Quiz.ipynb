# %%
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'

# %%
import pandas as pd
import numpy as np

# %%
fuel_data = pd.read_csv(url, error_bad_lines=False)

# %%
fuel_data.groupby('fuel_cost_per_unit_burned')['fuel_cost_per_unit_burned'].count()
# Out:
# fuel_cost_per_unit_burned
# -276.080       1
# -174.670       1
# -123.310       1
# -119.040       1
# -85.760        1
#               ..
#  65137.588     1
#  69785.215     1
#  80459.000     1
#  83538.000     1
#  139358.000    1
# Name: fuel_cost_per_unit_burned, Length: 19416, dtype: int64

# %%
fuel_data.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2001_12_134_2_9               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
fuel_data.groupby('fuel_cost_per_unit_burned').first()
# Out:
#                                           record_id  utility_id_ferc1  \
# fuel_cost_per_unit_burned
# -276.080                    f1_fuel_2000_12_194_3_3               194
# -174.670                    f1_fuel_2000_12_194_3_6               194
# -123.310                   f1_fuel_2000_12_194_2_15               194
# -119.040                    f1_fuel_2003_12_281_1_4               281
# -85.760                     f1_fuel_1995_12_194_5_9               194
# ...                                             ...               ...
#  65137.588                   f1_fuel_2012_12_7_7_13                 7
#  69785.215                   f1_fuel_2011_12_7_7_13                 7
#  80459.000                  f1_fuel_2014_12_177_2_7               177
#  83538.000                  f1_fuel_2011_12_132_1_2               132
#  139358.000                 f1_fuel_2014_12_147_0_2               147
#
#                            report_year     plant_name_ferc1  \
# fuel_cost_per_unit_burned
# ...

# %%
import scipy.stats as stats

# %%
kurtosis_scipy = stats.kurtosis(fuel_data)
kurtosis_pandas = pd.DataFrame(fuel_data).kurtosis('fuel_cost_per_unit_burned')[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7e855904d1f0> in <module>
# ----> 1 kurtosis_scipy = stats.kurtosis('fuel_data')
#       2 kurtosis_pandas = pd.DataFrame('fuel_data').kurtosis('fuel_cost_per_unit_burned')[1]
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in kurtosis(a, axis, fisher, bias, nan_policy)
#    1266
#    1267     n = a.shape[axis]
# -> 1268     m2 = moment(a, 2, axis)
#    1269     m4 = moment(a, 4, axis)
#    1270     zero = (m2 == 0)
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in moment(a, moment, axis, nan_policy)
#     968         return np.array(mmnt)
#     969     else:
# --> 970         return _moment(a, moment, axis)
#     971
#     972
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in _moment(a, moment, axis)
#    1008
#    1009         # Starting point for exponentiation by squares
# ...

# %%
print(kurtosis_scipy, kurtosis_pandas)

# %%
pd.DataFrame(fuel_data).kurtosis('fuel_cost_per_unit_burned')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-038dab11f2c9> in <module>
# ----> 1 pd.DataFrame(fuel_data).kurtosis('fuel_cost_per_unit_burned')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11215             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11216         return self._reduce(
# > 11217             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11218         )
#   11219
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7858         else:
#    7859             # TODO: Make other agg func handle axis=None properly
# -> 7860             axis = self._get_axis_number(axis)
#    7861             labels = self._get_agg_axis(axis)
# ...

# %%
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
percent_missing = fuel_data.isnull().sum() * 100 / len(fuel_data)

# %%
print(percent_missing)
# Out:
# record_id                       0.000000
# utility_id_ferc1                0.000000
# report_year                     0.000000
# plant_name_ferc1                0.000000
# fuel_type_code_pudl             0.000000
# fuel_unit                       0.609694
# fuel_qty_burned                 0.000000
# fuel_mmbtu_per_unit             0.000000
# fuel_cost_per_unit_burned       0.000000
# fuel_cost_per_unit_delivered    0.000000
# fuel_cost_per_mmbtu             0.000000
# dtype: float64

# %%
corr, _ = fuel_data(record_id , fuel_cost_per_unit_burned)
print('Pearsons correlation: %.3f' % corr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-0dca0683c8dd> in <module>
# ----> 1 corr, _ = fuel_data('record_id' , 'fuel_cost_per_unit_burned')
#       2 print('Pearsons correlation: %.3f' % corr)
#
# TypeError: 'DataFrame' object is not callable

# %%
fuel_data.groupby('fuel_cost_per_unit_burned').{'fuel_type_code_pudl': ['coal']}
change_percent = ((float(current)-previous)/previous)*100
# Out:
#   File "<ipython-input-28-21d4872885ea>", line 1
#     fuel_data.groupby('fuel_cost_per_unit_burned').{'fuel_type_code_pudl': ['coal']}
#                                                    ^
# SyntaxError: invalid syntax

# %%
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fcpud = pd.DataFrame(fuel_data, fuel_cost_per_unit_delivered)
max_value = max(fuel_cost_per_unit_delivered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b136308654bd> in <module>
# ----> 1 df = pd.DataFrame(fuel_data, fuel_cost_per_unit_delivered)
#       2 max_value = max(fuel_cost_per_unit_delivered)
#
# NameError: name 'fuel_cost_per_unit_delivered' is not defined
